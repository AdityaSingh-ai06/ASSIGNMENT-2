# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaSingh-ai06/ASSIGNMENT-2/blob/main/Ashirwad_Aditya_Singh_B24BS1075.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ashirwad_Aditya_Singh_B24BS1075


# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import matplotlib.pyplot as plt

# Make plots render at higher resolution (prevents cropping)
set_matplotlib_formats('retina')
plt.rcParams['figure.figsize'] = [12, 8]  # wider, taller
plt.rcParams['figure.dpi'] = 150          # higher resolution



# Read the CSV file
df = pd.read_csv("student_performance.csv")

# Display the full dataset
print("=== Student Performance Dataset ===")
print(df)

# Display basic information about the dataset
print("\n=== Dataset Info ===")
print(df.info())

# Display first 5 rows (preview)
print("\n=== First 5 Rows ===")
print(df.head())
# Out:
# === Student Performance Dataset ===
#        ID  Age  Study_Hours  Exam_Score
# 0       1   24         7.28        71.0
# 1       2   21         5.82        99.1
# 2       3   22         3.79        55.4
# 3       4   24         8.32        85.1
# 4       5   20         7.16        98.3
# ..    ...  ...          ...         ...
# 995   996   22         7.01        84.1
# 996   997   18         6.58        83.1
# 997   998   21         5.17        73.6
# 998   999   25         4.42        81.2
# 999  1000   20         8.77       100.0
#
# [1000 rows x 4 columns]
#
# === Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1000 non-null   int64
#  1   Age          1000 non-null   int64
#  2   Study_Hours  1000 non-null   float64
#  3   Exam_Score   1000 non-null   float64
# dtypes: float64(2), int64(2)
# ...

# %%
#QUESTION_1
print("QUESTION_1")


# Calculate the mean of Study Hours
mean_study_hours = df['Study_Hours'].mean()
print("\nMean of Study Hours:", mean_study_hours)
# Out:
# QUESTION_1
#
# Mean of Study Hours: 5.49788

# %%
# Question 2


print("QUESTION_2")


# Display the dataset summary
print("=== Dataset Preview ===")
print(df.head())

# --- Statistical Calculations ---

# Mean
mean_study = df['Study_Hours'].mean()
mean_score = df['Exam_Score'].mean()

# Median
median_study = df['Study_Hours'].median()
median_score = df['Exam_Score'].median()

# Variance
variance_study = df['Study_Hours'].var()
variance_score = df['Exam_Score'].var()

# Standard Deviation
std_study = df['Study_Hours'].std()
std_score = df['Exam_Score'].std()

# --- Display Results ---
print("\n=== Descriptive Statistics ===")
print(f"Mean of Study Hours: {mean_study:.2f}")
print(f"Mean of Exam Score: {mean_score:.2f}")
print(f"Median of Study Hours: {median_study:.2f}")
print(f"Median of Exam Score: {median_score:.2f}")
print(f"Variance of Study Hours: {variance_study:.2f}")
print(f"Variance of Exam Score: {variance_score:.2f}")
print(f"Standard Deviation of Study Hours: {std_study:.2f}")
print(f"Standard Deviation of Exam Score: {std_score:.2f}")

# --- Optional: Use describe() for quick summary ---
print("\n=== Quick Summary Using describe() ===")
print(df[['Study_Hours', 'Exam_Score']].describe())
# Out:
# QUESTION_2
# === Dataset Preview ===
#    ID  Age  Study_Hours  Exam_Score
# 0   1   24         7.28        71.0
# 1   2   21         5.82        99.1
# 2   3   22         3.79        55.4
# 3   4   24         8.32        85.1
# 4   5   20         7.16        98.3
#
# === Descriptive Statistics ===
# Mean of Study Hours: 5.50
# Mean of Exam Score: 77.41
# Median of Study Hours: 5.50
# Median of Exam Score: 79.70
# Variance of Study Hours: 6.90
# Variance of Exam Score: 325.48
# Standard Deviation of Study Hours: 2.63
# Standard Deviation of Exam Score: 18.04
#
# === Quick Summary Using describe() ===
#        Study_Hours   Exam_Score
# count  1000.000000  1000.000000
# mean      5.497880    77.413400
# std       2.626243    18.041006
# min       1.040000    38.000000
# 25%       3.135000    62.100000
# 50%       5.505000    79.700000
# 75%       7.750000    95.100000
# max      10.000000   100.000000

# %%
# Question 3

print("QUESTION_3")

# --- SCATTER PLOT: Study Hours vs Exam Score ---
plt.figure(figsize=(8,6))
plt.scatter(df['Study_Hours'], df['Exam_Score'], color='blue', alpha=0.6, edgecolor='k')

# Add labels and title
plt.title("Relationship between Study Hours and Exam Score", fontsize=14, fontweight='bold')
plt.xlabel("Study Hours", fontsize=12)
plt.ylabel("Exam Score", fontsize=12)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# --- OPTIONAL: Correlation check ---
correlation = df['Study_Hours'].corr(df['Exam_Score'])
print(f"\nCorrelation between Study Hours and Exam Score: {correlation:.2f}")
# Out:
# QUESTION_3
# Correlation between Study Hours and Exam Score: 0.91

# %%
d                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     # Question 4

print("QUESTION_4")



# --- HISTOGRAMS for Study Hours and Exam Score ---
plt.figure(figsize=(12, 5))

# Histogram for Study Hours
plt.subplot(1, 2, 1)
plt.hist(df['Study_Hours'], bins=15, color='skyblue', edgecolor='black')
plt.title("Distribution of Study Hours", fontsize=13, fontweight='bold')
plt.xlabel("Study Hours")
plt.ylabel("Frequency")

# Histogram for Exam Score
plt.subplot(1, 2, 2)
plt.hist(df['Exam_Score'], bins=15, color='lightgreen', edgecolor='black')
plt.title("Distribution of Exam Scores", fontsize=13, fontweight='bold')
plt.xlabel("Exam Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# --- BOX PLOTS for detecting outliers ---
plt.figure(figsize=(10, 5))

# Boxplots side by side
plt.subplot(1, 2, 1)
plt.boxplot(df['Study_Hours'], patch_artist=True, boxprops=dict(facecolor="skyblue"))
plt.title("Boxplot of Study Hours")
plt.ylabel("Study Hours")

plt.subplot(1, 2, 2)
plt.boxplot(df['Exam_Score'], patch_artist=True, boxprops=dict(facecolor="lightgreen"))
plt.title("Boxplot of Exam Scores")
plt.ylabel("Exam Score")

plt.tight_layout()
plt.show()
# Out:
# QUESTION_4

# %%
# Question 5


print("QUESTION_5")


# --- Prepare the data for regression ---
X = df[['Study_Hours']]   # Independent variable (2D array)
y = df['Exam_Score']      # Dependent variable

# --- Create and train the model ---
model = LinearRegression()
model.fit(X, y)

# --- Predict Exam Score based on Study Hours ---
y_pred = model.predict(X)

# --- Visualization ---
plt.figure(figsize=(8,6))

# Scatter plot of actual data
plt.scatter(df['Study_Hours'], df['Exam_Score'], color='blue', alpha=0.6, edgecolor='k', label='Actual Data')

# Plot regression line
plt.plot(df['Study_Hours'], y_pred, color='red', linewidth=2, label='Regression Line')

# Add labels and title
plt.title("Linear Regression: Study Hours vs Exam Score", fontsize=14, fontweight='bold')
plt.xlabel("Study Hours", fontsize=12)
plt.ylabel("Exam Score", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# --- Display regression equation and model performance ---
print("=== Linear Regression Equation ===")
print(f"Exam_Score = {model.intercept_:.2f} + {model.coef_[0]:.2f} × Study_Hours")

# --- Optional: Model performance ---
r_squared = model.score(X, y)
print(f"R-squared Value: {r_squared:.3f}")
# Out:
# QUESTION_5
# === Linear Regression Equation ===
# Exam_Score = 42.87 + 6.28 × Study_Hours
# R-squared Value: 0.836

# %%
# Question 6

print("QUESTION_6")


# --- Prepare data ---
X = df[['Study_Hours']]   # Independent variable
y = df['Exam_Score']      # Dependent variable

# --- Train the Linear Regression Model ---
model = LinearRegression()
model.fit(X, y)

# --- Predict Exam Score for new Study Hours ---
# Example: Predict for 5, 8, and 10 hours of study
new_hours = np.array([[5], [8], [10]])
predicted_scores = model.predict(new_hours)

# --- Display predictions ---
for h, p in zip(new_hours.flatten(), predicted_scores):
    print(f"Predicted Exam Score for {h} Study Hours = {p:.2f}")

# --- Optional: Display model equation again ---
print("\n=== Regression Equation ===")
print(f"Exam_Score = {model.intercept_:.2f} + {model.coef_[0]:.2f} × Study_Hours")

# --- Optional: Model Performance ---
r2 = model.score(X, y)
print(f"R-squared Value: {r2:.3f}")
# Out:
# QUESTION_6
# Predicted Exam Score for 5 Study Hours = 74.29
# Predicted Exam Score for 8 Study Hours = 93.13
# Predicted Exam Score for 10 Study Hours = 105.70
#
# === Regression Equation ===
# Exam_Score = 42.87 + 6.28 × Study_Hours
# R-squared Value: 0.836
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Question 7

print("QUESTION_7")


# --- Prepare the data ---
X = df[['Study_Hours']]   # Independent variable
y = df['Exam_Score']      # Dependent variable

# --- Train the Linear Regression model ---
model = LinearRegression()
model.fit(X, y)

# --- Predict Exam Scores using the trained model ---
y_pred = model.predict(X)

# --- Model Evaluation Metrics ---
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = model.score(X, y)

# --- Display the results ---
print("=== Model Evaluation ===")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared Value: {r2:.3f}")

# --- Visualization: Actual vs Predicted ---
plt.figure(figsize=(8,6))
plt.scatter(y, y_pred, color='purple', alpha=0.6, edgecolor='k')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linewidth=2, label='Perfect Prediction Line')

plt.title("Actual vs Predicted Exam Scores", fontsize=14, fontweight='bold')
plt.xlabel("Actual Exam Score", fontsize=12)
plt.ylabel("Predicted Exam Score", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# QUESTION_7
# === Model Evaluation ===
# Mean Absolute Error (MAE): 5.69
# Mean Squared Error (MSE): 53.21
# Root Mean Squared Error (RMSE): 7.29
# R-squared Value: 0.836
